# %%
import os
import shutil
import send2trash
import re

# %%
def walk_through_directory(directory):
    """
    A function that walks through a directory and prints the name of each file,
    folder and subfolder in the directory.

    Parameters
    ----------
    directory : str
        The directory to walk through.
    
    Returns
    -------
    None

    Example:
        >>> walk_through_directory('/home/user/Desktop')
    """
    for folder, subfolder, files in os.walk(directory):
        print(f"Current Folder: {folder}")
        print("Subfolders:", subfolder)
        for file in files:
            print(file)

# %%
def organize_by_format(directory, formats, destination):
    """
    A function to organize files by format, eg. by images, videos, audio, etc.\\
    The functions organizes all the files with some specific format in a\\
    specific folder. These files need not be in the parent directory, the\\
    function will walk through the whole directory.

    Parameters
    ----------
    directory : str
        The directory which we need to organize.
    formats : list
        A list of file formats to organize.
    destination : str
       The destination directory to move the files to.

    Returns
    -------
        None
        
    Example:
        >>> organize_by_format("/home/user/Desktop/", ["jpg", "png"], "/home/user/Desktop/images")
    """
    new_dir = os.path.join(directory, destination)
    if not os.path.exists(new_dir):
        print("Creating the directory: ", new_dir)
        os.mkdir(new_dir)
    else:
        print("Directory already exists")

    for folder, subfolder, files in os.walk(directory):
        print(f"Current Folder: {folder}")
        for file in files:
            if folder == new_dir:
                continue
            for format in formats:
                if file.endswith(format):
                    original_dir = os.path.join(folder, file)
                    shutil.move(original_dir, new_dir)
                    
    print("Organization complete!")

# %%
def calculate_directory_size(directory, output_unit = 'kb', exclude_files_by_format = None, 
    exclude_files_by_size = None, exclude_files_units = None, number_of_files = False):
    """
    A function to calculate the size of a directory.

    Parameters
    ----------
    directory : str
        The directory to calculate the size of.
    
    output_unit : str
        The unit to output the size in. Default is kb.\\
        valid units are: b, kb, mb and gb
    
    exclude_files_format: list
        A list of file formats to exclude from the size calculation.\\
        Default is None.

    exclude_files_size: int
        Every file with a size smaller than this value will be excluded\\
        from the size calculation. Default is `None`.\\
        The unit of the size is specified by the `exclude_files_units` argument. If not, it's assumed\\
        to be same as the `output_unit`.
    
    exclude_files_units: str
        The unit of the exclude_files_size argument.\\
        Default is kb. valid units are: b, kb, mb and gb
   
    number_of_files: bool 
        If True, the number of files in the directory will also be returned.\\
        Note: Only those files which are not excluded will be counted.

    Returns
    -------
    int/tuple of two ints
        The size of the directory in units of `output_unit`.

    Example
    -------
        >>> calculate_directory_size("/home/user/Desktop/", "mb", ["jpg", "png"], 100)
    """
    #Initialize the total_size variable
    total_size = 0
    num_files = 0
    files_excluded = 0

    #Creating a conversion dictionary
    conversion_dict = {
        'b': 1,
        'kb': 1024,
        'mb': 1024**2,
        'gb': 1024**3,
        None: 1024
    }

    try:
        #Get the output unit conversion factor
        output_unit_factor = conversion_dict[output_unit.lower()]
        
        #Get the exclude_files_size conversion factor
        if exclude_files_units is not None:
            exclude_files_size_factor = conversion_dict[exclude_files_units.lower()]
        else:
            exclude_files_size_factor = output_unit_factor
    except KeyError:
        print("Invalid output_unit")
        print("Valid units are: b, Kb, Mb and Gb")
        return None
    
    for folder, subfolder, files in os.walk(directory):
        for file in files:
            file_size = os.path.getsize(os.path.join(folder, file))

            #Excluding the files with the specified format
            if exclude_files_by_format is not None:
                for format in exclude_files_by_format:
                    if file.endswith(format):
                        files_excluded += 1
                        file_size = 0
                        num_files += 0
                        break

            #Excluding the files with the specified size
            if exclude_files_by_size is not None:
                if file_size < exclude_files_by_size * exclude_files_size_factor:
                    files_excluded += 1
                    file_size = 0
                    num_files += 0

            total_size += file_size
            num_files += 1
        
    total_file_size = round(total_size / output_unit_factor, 2)

    #Printing number of excluded files
    if exclude_files_by_format or exclude_files_by_size:
        print(f"Total number of files excluded is: {files_excluded}")

    #Printing the outputs
    if number_of_files:
        print(f"The size of the directory is: {total_file_size} {output_unit.title()}")
        print(f"The number of files in the directory is: {num_files}")
        print(f"Numbers of files included in the size calculation: {num_files - files_excluded}")
        return total_file_size, num_files
    else:
        print(f"The size of the directory is: {total_file_size} {output_unit.title()}")
        return total_file_size

# %%
calculate_directory_size(r"C:\Users\harik\Downloads",exclude_files_by_size=1000, exclude_files_by_format=['png'],
     number_of_files=True, output_unit = "mB", exclude_files_units = "kB")
# Out:
# Total number of files excluded is: 287
# The size of the directory is: 12592.2 Mb
# The number of files in the directory is: 482
# Numbers of files included in the size calculation: 195
# (12592.2, 482)

# %%
calculate_directory_size(r"C:\Users\harik\Downloads", number_of_files=True, output_unit = "mB")
# Out:
# The size of the directory is: 12667.52 Mb
# The number of files in the directory is: 482
# Numbers of files included in the size calculation: 482
# (12667.52, 482)

# %%
def large_files_in_directory(directory, min_size = 10, unit = 'mb', verbose = False, exclude_files_by_format =None):
    """
    Prints the names of the files and location in the directory which are larger than the specified\\
         size.

    Parameters
    ----------
    directory : str
        The directory to search for the files.t.

    min_size : int
        The minimum size of the files to be printed. Default is 10.\\
        The unit of the size is specified by the `unit` argumen
    
    unit : str
        The unit of the min_size argument.\\
        Default is mb. valid units are: b, kb, mb and gb
    
    verbose : bool
        If True, the size of the files will be printed.\\
        Default is False.

    exclude_files_by_format: list
        A list of file formats to exclude from the size calculation.\\
        Default is None.

    Returns
    -------
    list:
        A list of the files which are larger than the specified size.
    
    Example
    -------
        >>> large_files_in_directory("/home/user/Desktop/", min_size = 10, unit = 'mb')
    """

    total_files = 0
    total_space = 0
    found_files = []
    excluded = 0
    #Creating a conversion dictionary
    conversion_dict = {
        'b': 1,
        'kb': 1024,
        'mb': 1024**2,
        'gb': 1024**3,
    }

    try:
        #Get the output unit conversion factor
        unit_factor = conversion_dict[unit.lower()]
    except KeyError:
        print("Invalid unit")
        print("Valid units are: b, Kb, Mb and Gb")
        return None
    print("Searching...")
    for folder, subfolder, files in os.walk(directory):
        for file in files:
            try:
                file_size = os.path.getsize(os.path.join(folder, file))
            except FileNotFoundError:
                continue
            file_size_in_unit = round(file_size / unit_factor, 2)
            
            if exclude_files_by_format is not None:
                for format in exclude_files_by_format:
                    if file.endswith(format):
                        file_size_in_unit = 0
                        excluded += 1
                        break

            if file_size_in_unit > min_size:
                total_files += 1
                total_space += file_size_in_unit
                if verbose:
                    print(f"'{file}', with size of {file_size_in_unit} {unit.title()} is larger than {min_size} {unit.title()}")
                    print(f"\tFound at: {folder}")
                found_files.append(os.path.join(folder, file))

    if total_files == 0:
        print("No files found")
    else:
        print(f"Total number of files found: {total_files}")
        print(f"Number of files excluded: {excluded}")
        print(f"Total space of files found: {total_space} {unit.title()}")
        print("Done!")
    return found_files

# %%
files = large_files_in_directory(r"C:\Users\harik", min_size = 100, unit = 'mb')
# Out:
# Searching...
# Total number of files found: 347
# Number of files excluded: 0
# Total space of files found: 107549.42999999996 Mb
# Done!

# %%
# files
# Out:
# ['C:\\Users\\harik\\anaconda3\\Lib\\site-packages\\tensorflow\\python\\_pywrap_tensorflow_internal.pyd',
#  'C:\\Users\\harik\\anaconda3\\Lib\\site-packages\\xgboost\\lib\\xgboost.dll',
#  'C:\\Users\\harik\\anaconda3\\pkgs\\mkl-2020.2-256.conda',
#  'C:\\Users\\harik\\anaconda3\\pkgs\\mkl-2021.4.0-haa95532_640.conda',
#  'C:\\Users\\harik\\anaconda3\\pkgs\\pandoc-2.11-h9490d1a_0\\Scripts\\pandoc.exe',
#  'C:\\Users\\harik\\anaconda3\\pkgs\\pandoc-2.12-haa95532_0\\Scripts\\pandoc.exe',
#  'C:\\Users\\harik\\anaconda3\\Scripts\\pandoc.exe',
#  'C:\\Users\\harik\\AppData\\Local\\atom\\app-1.46.0\\resources\\app.asar',
#  'C:\\Users\\harik\\AppData\\Local\\atom\\app-1.47.0\\resources\\app.asar',
#  'C:\\Users\\harik\\AppData\\Local\\atom\\packages\\atom-1.47.0-delta.nupkg',
#  'C:\\Users\\harik\\AppData\\Local\\atom\\packages\\atom-1.47.0.nupkg',
#  'C:\\Users\\harik\\AppData\\Local\\BlueStacksSetup\\BlueStacksInstaller_4.150.0.1118_native_09ba7d29227824f9f5b301587b5eda39.exe',
#  'C:\\Users\\harik\\AppData\\Local\\GitHubDesktop\\app-2.9.4\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\GitHubDesktop\\app-2.9.5\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\GitHubDesktop\\app-2.9.6\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\GitHubDesktop\\packages\\GitHubDesktop-2.9.5.nupkg',
#  'C:\\Users\\harik\\AppData\\Local\\GitHubDesktop\\packages\\GitHubDesktop-2.9.6.nupkg',
#  'C:\\Users\\harik\\AppData\\Local\\Google\\Chrome\\User Data\\Default\\Cache\\data_3',
#  'C:\\Users\\harik\\AppData\\Local\\Google\\DriveFS\\109770288982294379454\\metadata_sqlite_db',
#  'C:\\Users\\harik\\AppData\\Local\\Google\\DriveFS\\109770288982294379454\\mirror_metadata_sqlite.db',
#  'C:\\Users\\harik\\AppData\\Local\\Google\\DriveFS\\migration\\bns_config\\user_default\\sync_log.log',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Internet Explorer\\Indexed DB\\Internet.edb',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Outlook\\Offline Address Books\\c341ea09-3008-4287-81a6-80a1d3ddd7e6\\details.tmp',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Outlook\\Offline Address Books\\c341ea09-3008-4287-81a6-80a1d3ddd7e6\\udetails.oab',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Teams\\current\\Teams.exe',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Teams\\packages\\Teams-1.4.00.29469-full.nupkg',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Teams\\previous\\Teams.exe',
#  'C:\\Users\\harik\\AppData\\Local\\Microsoft\\Windows\\WebCache\\WebCacheV01.dat',
#  'C:\\Users\\harik\\AppData\\Local\\pip\\cache\\http\\8\\c\\e\\2\\9\\8ce29956162a0cd1a99a6ef08accd89eb726e30fe466dbbbe2c458d6',
#  'C:\\Users\\harik\\AppData\\Local\\pip\\cache\\http\\c\\6\\a\\9\\6\\c6a96fbef209424b537e242f44e11894f63c6081582b6782d2b9ceb0',
#  'C:\\Users\\harik\\AppData\\Local\\pip\\cache\\http\\f\\5\\6\\1\\3\\f5613eae2af16b48090d53e8f4682b3e81ce950ec05e501f1ae75ef0',
#  'C:\\Users\\harik\\AppData\\Local\\pip\\cache\\wheels\\23\\f6\\d3\\110e53bd43baeb8d7d38049733d48e39cbecd056f01dba7ee8\\pyspark-3.2.0-py2.py3-none-any.whl',
#  'C:\\Users\\harik\\AppData\\Local\\Postman\\app-9.5.0\\Postman.exe',
#  'C:\\Users\\harik\\AppData\\Local\\Postman\\app-9.5.0\\resources\\app.asar',
#  'C:\\Users\\harik\\AppData\\Local\\Postman\\app-9.7.1\\Postman.exe',
#  'C:\\Users\\harik\\AppData\\Local\\Postman\\app-9.7.1\\resources\\app.asar',
#  'C:\\Users\\harik\\AppData\\Local\\Postman\\packages\\Postman-win64-9.7.1-full.nupkg',
#  'C:\\Users\\harik\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe',
#  'C:\\Users\\harik\\AppData\\Local\\Programs\\mongosh\\mongosh.exe',
#  'C:\\Users\\harik\\AppData\\Local\\Programs\\Notion\\Notion.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempb\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempd\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempg\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempk\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempm\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempo\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempq\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\temps\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempv\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempx\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempz\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempα\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempγ\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempε\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\SquirrelTemp\\tempη\\lib\\net45\\GitHubDesktop.exe',
#  'C:\\Users\\harik\\AppData\\Local\\WhatsApp\\app-2.2134.10\\WhatsApp.exe',
#  'C:\\Users\\harik\\AppData\\Local\\WhatsApp\\app-2.2134.10\\resources\\app.asar',
#  'C:\\Users\\harik\\AppData\\Local\\WhatsApp\\app-2.2138.14\\resources\\app.asar',
#  'C:\\Users\\harik\\AppData\\Roaming\\Code\\CachedExtensionVSIXs\\ms-dotnettools.csharp-1.23.17-win32-x64',
#  'C:\\Users\\harik\\AppData\\Roaming\\Foxit Software\\Addon\\Foxit PDF Reader\\Install\\Reader_en_11.1.0.52543.fzip',
#  'C:\\Users\\harik\\AppData\\Roaming\\Foxit Software\\Addon\\Foxit Reader\\Install\\updater\\Reader_en_11.0.0.49893_5.fzip',
#  'C:\\Users\\harik\\AppData\\Roaming\\Microsoft\\Teams\\Cache\\data_3',
#  'C:\\Users\\harik\\Desktop\\Books\\Adobe Illustrator CC - Essentials Training Course\\12. Next Steps\\2. BONUS Software Updates.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\First Era\\Final Empire\\Brandon Sanderson - Mistborn 01 - The Final Empire, Part 1.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\First Era\\Final Empire\\Brandon Sanderson - Mistborn 01 - The Final Empire, Part 2.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\First Era\\Hero of Ages\\Brandon Sanderson - Mistborn 03 - The Hero of Ages, Part 1.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\First Era\\Hero of Ages\\Brandon Sanderson - Mistborn 03 - The Hero of Ages, Part 2.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\First Era\\Well of Ascension\\Brandon Sanderson - Mistborn 02 - Well of Ascension, Part 1.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\First Era\\Well of Ascension\\Brandon Sanderson - Mistborn 02 - Well of Ascension, Part 2.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Brandon Sanderson\\Mistborn\\Second Era\\Alloy of Law\\Brandon Sanderson - Mistborn 04 - The Alloy of Law.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Chronicles of Narnia\\01The Lion, the Witch and the Wardrobe\\Chronicles of Narnia 02 - The Lion, the Witch and the Wardrobe.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\01. Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\02. Dune Messiah.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\03. Children of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\04. God Emperor of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\05. Heretics of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\06. Chapterhouse_ Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\07. Hunters of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\01 - Dune Saga\\08. Sandworms of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\02 - Prelude to Dune\\01. House Atreides.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\02 - Prelude to Dune\\02. House Harkonnen.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\02 - Prelude to Dune\\03. House Corrino.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\03 - Legends of Dune\\01. The Butlerian Jihad.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\03 - Legends of Dune\\02. The Machine Crusade.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\03 - Legends of Dune\\03. The Battle of Corrin.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\04 - Hunters of Dune\\Hunters of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\05 - Sandworms of Dune\\Sandworms of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\06 - Heroes of Dune\\01. Paul of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\06 - Heroes of Dune\\02. The Winds of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\07 - Great Schools of Dune\\01. Sisterhood of Dune\\Sisterhood of Dune.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\07 - Great Schools of Dune\\02. Mentats of Dune\\Mentats of Dune Part 1.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\07 - Great Schools of Dune\\02. Mentats of Dune\\Mentats of Dune Part 2.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Dune\\07 - Great Schools of Dune\\02. Mentats of Dune\\Mentats of Dune Part 3.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\George Orwell\\George Orwell Collection - 1984.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Hunger Games\\Catching Fire.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Hunger Games\\The Hunger Games.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Kane Chronicles\\01 The Red Pyramid\\The Red Pyramid Part1.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Kane Chronicles\\01 The Red Pyramid\\The Red Pyramid Part2.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Kane Chronicles\\02 The Throne of Fire\\01 The Throne of Fire.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Kane Chronicles\\02 The Throne of Fire\\02 The Throne of Fire.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Percy Jackson and the Olympians\\Percy Jackson Book 1 - The Lightning Thief by Rick Riordan.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Percy Jackson and the Olympians\\Percy Jackson Book 2 - The Sea of Monsters by Rick Riordan.m4b',
#  "C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Percy Jackson and the Olympians\\Percy Jackson Book 3 - The Titan's Curse by Rick Riordan.m4b",
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Percy Jackson and the Olympians\\Percy Jackson Book 4 - The Battle Of The Labyrinth by Rick Riordan.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\Percy Jackson and the Olympians\\Percy Jackson Book 5 - The Last Olympian by Rick Riordan.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\The Heroes of Olympus\\The Lost Hero\\1.The Lost Hero.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\The Heroes of Olympus\\The Lost Hero\\The Heroes of Olympus, Book One; The Lost Hero; ___ (Unabridged) Part 1.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Rick Riordan\\The Heroes of Olympus\\The Lost Hero\\The Heroes of Olympus, Book One; The Lost Hero; ___ (Unabridged) Part 2.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Sarah J Maas\\A Court of Thorns and Roses.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Sarah J Maas\\A Court of Mist and Fury (A Court of Thorns and Roses #2)\\A Court of Mist and Fury.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Sarah J Maas\\Crown of Midnight\\Crown of Midnight  Part 2.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Sarah J Maas\\Crown of Midnight\\Crown of Midnight Part 1.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\Sarah J Maas\\Sarah J. Maas - Throne of Glass 3 - Heir of Fire\\Sarah J. Maas - Throne of Glass 3 - Heir of Fire .mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The First Law\\The Blade Itself\\Joe Abercrombie - The Blade Itself The First Law Book One (Unabridged)\\The Blade Itself The First Law Book One (Unabridged).m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The First Law\\The Blade Itself\\Joe Abercrombie - The Blade Itself The First Law Book One (Unabridged) Part 1\\The Blade Itself The First Law Book One (Unabridged) Part 1.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The First Law\\The Blade Itself\\Joe Abercrombie - The Blade Itself The First Law Book One (Unabridged) Part 2\\The Blade Itself The First Law Book One (Unabridged) Part 2.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The First Law\\The Blade Itself\\Joe Abercrombie - The Blade Itself The First Law Book One (Unabridged) Part 3\\The Blade Itself The First Law Book One (Unabridged) Part 3.m4b',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The Lord of the Rings\\02 Book I_ The Ring Sets Out.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The Lord of the Rings\\03 Book II_ The Ring Goes South.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The Lord of the Rings\\04 Book III_ The Treason of Isengard.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The Lord of the Rings\\05 Book IV_ The Ring Goes East.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The Lord of the Rings\\06 Book V_ The War of the Ring.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Audiobooks\\The Lord of the Rings\\07 Book VI_ The End of the Third Age.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\10. Type Graphics Advanced Text Animation & Effects\\15. Practice Activity Tutorial News Text.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\12. Working with Masks & Effects for VideosImages\\7. Creating Curved Masks Using the Pen Tool.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\16. Visual Time Effects Time Games with Videos\\3. Time Games - Playing with Frames Per Seconds (FPS).mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\16. Visual Time Effects Time Games with Videos\\4. TimeWarp Effects - Speed.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\16. Visual Time Effects Time Games with Videos\\7. Mixing Video Speeds - Time Remap.mp4',
#  "C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\19. Advanced 3D - How to Create and Animate 3D Cameras\\5. How to Move  the Camera using it's 3D Axis System.mp4",
#  "C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\19. Advanced 3D - How to Create and Animate 3D Cameras\\6. How to Animate  the Camera using it's 3D Axis System.mp4",
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\19. Advanced 3D - How to Create and Animate 3D Cameras\\7. How to Create and Animate an Orbit Null for the Camera.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\25. Animation Presets - Using, Editing and Saving Your Presets\\5. How to Apply and Work with Fade Presets.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\27. Specialized Effects Motion Tracking\\11. Practice Activity Tutorial - Dancing Bulbs.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\27. Specialized Effects Motion Tracking\\6. How to Attach & Animate Shapes.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\29. Specialized Effects Color Correction with the Lumetri Scope\\10.1 Color Correction Folder Final.zip.zip',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\29. Specialized Effects Color Correction with the Lumetri Scope\\2.1 Color Correction Startup folder.zip.zip',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\31. Specialized Effects Separating Background  Foreground- Rotoscoping\\5. How to Propagate the Strokes.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\4. How to Create Motion (Animate) - Create Your First Motion Graphics Projects\\14. The YouTube Project DesignAnimateSequence.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\4. How to Create Motion (Animate) - Create Your First Motion Graphics Projects\\18. Challenge & Practice Activity Animate your layers.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\40. Your Complete Guide to the Audio Spectrum Effect - Create awesome Sound Waves\\10. Practice Activities Tutorial Audio Spectrum Effect.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\41. Your Complete Guide to the Radio Wave Effect in its Multiple Wave Types\\10. Practice Project - Radio Waves and CC Sphere.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe After Effects CC - Complete Course from Novice to Expert\\7. Spatial and Temporal Interpolation - Motion Path and Speed Control\\10. Practice Activity Tutorial.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\13. Transform, Distort & Blend\\4. How to make 3D gradient lettering blends in Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\13. Transform, Distort & Blend\\6. How to use the Puppet Warp Tool in Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\14. Web UI design\\1. How to use Adobe Illustrator for Web & UI design.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\15. Animating\\1. How to make an animated GIF using Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\16. Conclusion\\1. BONUS Software Updates 2019.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\16. Conclusion\\2. BONUS Software Updates 2020.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\16. Conclusion\\3. BONUS Software Updates 2021.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\2. Drawing\\4. How to draw flowing curves in Adobe Illustrator with the Width Tool.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\2. Drawing\\6. The best creation tool in Adobe Illustrator CC the shape builder tool.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\2. Drawing\\7. More shape builder goodness.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\4. Color & Patterns\\1. Advanced Color tips & tricks for Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\4. Color & Patterns\\13. Advanced repeating pattern swatches in Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\4. Color & Patterns\\3. How to color a real hand drawing using Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\4. Color & Patterns\\6. How to make gradients bend in Adobe Illustrator CC using Gradient Mesh.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\4. Color & Patterns\\9. How to make images Black & white in Illustrator & mix with color.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\5. Workflow Speed\\2. Advanced workflow tricks for Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\6. Typography\\2. How to put text type into the shape of a letter in Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\8. Depth, Perspective & 3D\\1. Introduction to 3D in Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\8. Depth, Perspective & 3D\\2. How to make Semi flat 3D icons & ui design using Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Illustrator CC - Advanced Training Course\\9. Charts & Graphs\\1. How to make a pie chart line graph & bar graph in Adobe Illustrator CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\1. Getting Started\\2.1 Exercise Files - Photoshop Essentials.zip.zip',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\10. Smart Objects\\1. What is a smart object in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\11. Transform & Distort\\1. How to bend a logo onto an image realistically in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\11. Transform & Distort\\6. How to create dripping paint text effect in Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\12. Retouching\\1. How to remove people & text from a picture in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\12. Retouching\\7. Enhancing eyes in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\13. Blending Modes\\2. Using blending modes as color accents in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\13. Blending Modes\\3. How to put images inside a bottle using Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\14. Visual Styles\\10. How to create the paper cut effect in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\14. Visual Styles\\7. How to create a vintage instagram Matte Photo in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\15. Artboards\\1. How to use an Artboard in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\16. Color modes & Resolution\\1. What is the difference between RGB and CMYK in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\16. Color modes & Resolution\\2. How do you change the resolution to 300dpi in Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\17. Brushes\\1. Basic introduction to using a wacom tablet with Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\17. Brushes\\2. How to create splatter paint effects in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\17. Brushes\\8. How to create smoke with an image inside it using Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\18. Shadows\\2. How to cast a realistic shadow on the ground in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\19. Export\\1. How to export images from Photoshop for print web & social media.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\2. Layers\\1. How to use layers in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\20. What next\\1. BONUS Software Updates.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\3. Color & Adjustment Layers\\6. How to add a gradient to an image & text in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\4. Shapes\\2. How to draw star square circle shape in Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\5. Text\\3. How to get text to follow a line or circle in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\13. How to select hair in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\17. How to get text to interact with ink & plants in Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\2. How to crop images inside of text.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\3. How to remove the background in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\6. How to put text behind a person in Adobe Photoshop CC.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\6.1 29 How to put text behind a person in Adobe Photoshop CC.psd.psd',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\8. Class project - Cut a person out & put them into another image in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\8. 8.Selections & Masking\\8.1 31 Class project - Cut a person out & put them into another image in Photoshop.psd.psd',
#  'C:\\Users\\harik\\Desktop\\Books\\Courses\\Adobe Photoshop CC – Essentials Training Course\\9. Filters\\5. How to create the Dotted Halftone Poster Effect in Photoshop.mp4',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\9th Doctor\\01 - Doctor Who - The Clockwise Man\\The Clockwise Man - Read by Glen McCready\\Doctor Who - The Clockwise Man.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\9th Doctor\\02 - Doctor Who - The Monsters Inside\\The Monsters Inside - Read by David Thorpe\\Doctor Who - The Monsters Inside.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\9th Doctor\\03 - Doctor Who - Winner Takes All\\Winner Takes All - Read by David Thorpe\\Doctor Who - Winner Takes All.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\10 - Doctor Who - The Nightmare of Black Island\\The Nightmare of Black Island - Read by Anthony Head\\07 - Doctor Who - The Nightmare of Black Island.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\11 - Doctor Who - The Art of Destruction\\The Art of Destruction - Audiobook read by Don Warrington\\08 - Doctor Who - The Art of Destruction.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\12 - Doctor Who - The Price Of Paradise\\The Price of Paradise - Read by Shaun Dingwall\\The Price Of Paradise.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\24 - Doctor Who - The Many Hands\\The Many Hands - Read by David Troughton\\Doctor Who - The Many Hands.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\33 - Doctor Who - The Nemonite Invasion\\The Nemonite Invasion - Read by Catherine Tate\\Doctor Who - The Nemonite Invasion.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\34 - Doctor Who - Judgement of the Judoon\\Judgment of the Judoon - Read by Nicholas Briggs\\32 - Doctor Who - Judgement of the Judoon (Unabridged).mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\35 - Doctor Who - The Slitheen Excursion\\The Slitheen Excursion - Read by Debbie Chazen\\Doctor Who - The Slitheen Excursion (Unabridged).mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\38 - Doctor Who - The Taking of Chelsea 426\\The Taking of Chelsea 426 - Read by Christopher Ryan\\29 - Doctor Who - The Taking of Chelsea 426 (Unabridged).mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\10\\39 - Doctor Who - Autonomy\\Autonomy - Read by Georgia Moffett\\Doctor Who - Autonomy (Unabridged).mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\11th Doctor\\45 - Doctor Who - Night of the Humans\\Night of the Humans - Read by Arthur Darvill\\Doctor Who - Night of the Humans.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\11th Doctor\\52 - Doctor Who - Nuclear Time\\Nuclear Time - Read by Nicholas Briggs\\Nuclear Time.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\AB\\11th Doctor\\58 - Doctor Who - The Way Through the Woods\\The Way Through the Woods - Read by Clare Corbett\\The Way Through the Woods.mp3',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\Comics\\Miniseries and one-shots (10th Doctor)\\08 The_Ten_Doctors.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\Interactive\\Solo-Play Adventure Games\\Doctor Who and the Rebel’s Gamble\\Source Files\\Doctor Who and the Rebel’s Gamble - William H., Jr. Keith.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Doctor Who\\Interactive\\Solo-Play Adventure Games\\Doctor Who and the Vortex Crystal\\Source Files\\Doctor Who and the Vortex Crystal - William H Keith Jr.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Brian Swimme\\The-Universe-is-a-Green-Dragon.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Encyclopædia Britannica\\Britannica-Concise-Encyclopedia.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Encyclopædia Britannica\\Britannica-Illustrated-Science-Library-16-Vol-S.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Encyclopædia Britannica\\Britannica-Student-Encyclopedia.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Encyclopædia Britannica\\My First Britannica\\My-First-Britannica-13-Volume-Set-.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Giles Sparrow\\Spaceflight-The-Complete-Story-From-Sputnik-to-.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\McGraw-Hill-Encyclopedia-of-Science-Technology\\McGraw-Hill-Encyclopedia-of-Science-Technology-.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Science Literature\\Richard Dawkins\\The-Magic-of-Reality-How-We-Know-What-s-Really-.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\Fearful Symmetry Is God a Geometer - Ian Stewart and Martin Golubitsky.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\Mathematical Apocrypha Redux - Steven G. Krantz.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\Mathematical Snapshots 3e - H. Steinhaus.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\Never at Rest A Biography of Isaac Newton - Richard S. Westfall.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\Remarkable Mathematicians From Euler to von Neumann - Ioan James.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\Symmetry in Chaos A Search for Pattern in Mathematics, Art, and Nature 2e - Field and Golubitsky.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\The Curvature of Spacetime Netwon, Einstein, and Gravitation - Harald Fritzsch.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\The New Quantum Universe - Tony Hey and Patrick Walters.pdf',
#  'C:\\Users\\harik\\Desktop\\Books\\Uncatogerised\\To Infinity and Beyond A Cultural History of the Infinite - Eli Maor.pdf',
#  'C:\\Users\\harik\\Documents\\My Tableau Repository\\Logs\\log_bk.txt',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Doctor.Who.2005.S14E00.Eve.Of.The.Daleks.720p.HEVC.x265-MeGusta[eztv.re].mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Star.Trek.Discovery.S04E05.1080p.HEVC.x265-MeGusta[eztv.re].mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Star.Trek.Discovery.S04E06.1080p.HEVC.x265-MeGusta[eztv.re].mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Book.of.Boba.Fett.S01E01.720p.HEVC.x265-MeGusta[eztv.re].mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E01.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E02.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E03.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E04.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E05.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E06.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E07.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E08.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arcane.S01.COMPLETE.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Arcane.S01E09.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Arrival (2016) [YTS.AG]\\Arrival.2016.720p.BluRay.x264-[YTS.AG].mp4',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Doctor.Who.2005.S13E03.720p.HDTV.x265-MiNX[TGx]\\Doctor.Who.2005.S13E03.720p.HDTV.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Dont Look Up (2021) [720p] [WEBRip] [YTS.MX]\\Dont.Look.Up.2021.720p.WEBRip.x264.AAC-[YTS.MX].mp4',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Encanto (2021) [720p] [WEBRip] [YTS.MX]\\Encanto.2021.720p.WEBRip.x264.AAC-[YTS.MX].mp4',
#  "C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E01-We're Back.mkv",
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E02-Aikido.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E03-48 Meters Underground.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E04-Boom, Boom, Ciao.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E05-The Red Boxes.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E06-Everything Seemed Insignificant.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E07-A Quick Vacation.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Money Heist aka La Casa de Papel S03 Season 03 Complete 720p WEB-DL x264-XpoZ\\Money Heist S03E08-Astray.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\No.Time.To.Die.2021.720p.AMZN.WEBRip.900MB.x264-GalaxyRG[TGx]\\No.Time.To.Die.2021.720p.AMZN.WEBRip.900MB.x264-GalaxyRG.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Radioactive.2020.720p.WEBRip.800MB.x264-GalaxyRG[TGx]\\Radioactive.2020.720p.WEBRip.800MB.x264-GalaxyRG.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Shang-Chi And The Legend Of The Ten Rings (2021) [720p] [BluRay] [YTS.MX]\\Shang-Chi.And.The.Legend.Of.The.Ten.Rings.2021.720p.BluRay.x264.AAC-[YTS.MX].mp4',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E01.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E02.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E03.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E04.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E05.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E06.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E07.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E08.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\Squid.Game.S01.COMPLETE.DUBBED.720p.NF.WEBRip.x264-GalaxyTV[TGx]\\Squid.Game.S01E09.DUBBED.720p.NF.WEBRip.x264-GalaxyTV.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E01.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E01.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E02.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E02.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E03.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E03.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E04.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E04.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E05.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E05.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E06.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E06.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E07.720p.WEB.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E07.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Wheel.of.Time.S01E08.720p.WEBRip.x265-MiNX[TGx]\\The.Wheel.of.Time.S01E08.720p.WEBRip.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E01.A.Grain.of.Truth.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E02.Kaer.Morhen.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E03.What.Is.Lost.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E04.Redanian.Intelligence.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E05.Turn.Your.Back.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E06.Dear.Friend.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E07.Voleth.Meir.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Documents\\Vuze Downloads\\The.Witcher.S02.720p.NF.WEBRip.DDP5.1.Atmos.x264-TEPES[rartv]\\The.Witcher.S02E08.Family.720p.NF.WEB-DL.DDP5.1.Atmos.x264-TEPES.mkv',
#  'C:\\Users\\harik\\Downloads\\Applications\\basic-miktex-21.6-x64.exe',
#  'C:\\Users\\harik\\Downloads\\Applications\\matlab_R2021a_win64.exe',
#  'C:\\Users\\harik\\Downloads\\Applications\\mongodb-windows-x86_64-5.0.4-signed.msi',
#  'C:\\Users\\harik\\Downloads\\Applications\\Postman-win64-9.3.1-Setup.exe',
#  'C:\\Users\\harik\\Downloads\\Applications\\strawberry-perl-5.32.1.1-64bit.msi',
#  'C:\\Users\\harik\\Downloads\\Applications\\TableauPublicDesktop-64bit-2021-4-2.exe',
#  'C:\\Users\\harik\\Downloads\\Applications\\Teams_windows_x64.exe',
#  'C:\\Users\\harik\\Downloads\\Archives\\Electronics-20211121T035900Z-001.zip',
#  'C:\\Users\\harik\\Downloads\\Archives\\Family-20210628T100318Z-001.zip',
#  'C:\\Users\\harik\\Downloads\\Archives\\Friends-20210628T094810Z-001.zip',
#  'C:\\Users\\harik\\Downloads\\Archives\\Mathematical Methods.zip',
#  'C:\\Users\\harik\\Downloads\\Archives\\Notability-20210810T082047Z-001.zip',
#  'C:\\Users\\harik\\Downloads\\Archives\\tensorflow-deep-learning-main.zip',
#  'C:\\Users\\harik\\Downloads\\Videos\\Doctor.Strange.2016.720p.Hindi.English.TheMoviesVerse.Com.mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\Hercules.2014.720p.Hindi.English.mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\Justice.League.(2017).720p.Dual.Audio.(Hin-Eng).[AllMoviesHub.in].mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\Loki.S01E06.480p.WEB-DL.Hindi-English.x264.MSub-[Mp4Moviez.Li] - Copy.mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\Loki.S01E06.480p.WEB-DL.Hindi-English.x264.MSub-[Mp4Moviez.Li].mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\Madras Cafe 2013 BluRay 720p Hindi AAC 5.1 x264 ESub - mkvCinemas [Telly].mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\Stardust.2007.720p.Hindi.English  themoviesflix.co.mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\What If 2021 S01E01 720p HEVC x265-MeGusta[eztv.re].mkv',
#  'C:\\Users\\harik\\Downloads\\Videos\\X-Men.10.Logan.(2017).720p.Dual.Audio.(Hin-Eng).[MoviesVerse.in].mkv',
#  'C:\\Users\\harik\\tensorflow_datasets\\downloads\\downl.tenso.org_examp_image_flowe_photoTFSs55Ear_4To2XDT2UOcd1b8b4KWLRk5acYPj5ZXZw.tgz',
#  'C:\\Users\\harik\\tensorflow_datasets\\tf_flowers\\3.0.1\\tf_flowers-train.tfrecord-00000-of-00002',
#  'C:\\Users\\harik\\tensorflow_datasets\\tf_flowers\\3.0.1\\tf_flowers-train.tfrecord-00001-of-00002',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Ice Age\\Ice Age The Meltdown.2006.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Ice Age\\Ice Age.2002.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Ice Age\\Ice.Age.Collision.Course.2016.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Ice Age\\Ice.Age.Continental.Drift.2012.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Ice Age\\Ice.Age.Dawn.the Dinosaurs.2009..mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Lion King\\The.Lion.King.19994.mkv',
#  "C:\\Users\\harik\\Videos\\Movies\\Animation\\Lion King\\The.Lion.King.2.Simba's.Pride.1998.mp4",
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Lion King\\The.Lion.King.3.2004.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Shrek\\Shrek.2.2004.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Shrek\\Shrek.2001.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Shrek\\Shrek.4.2010.mp4',
#  'C:\\Users\\harik\\Videos\\Movies\\Animation\\Shrek\\Shrek.The.Third.2007.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E01 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E02 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E03 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E04 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E05 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E06 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E07 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E08 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Drama\\Season 2\\(PlayHD.ooo) Money Heist S02E09 English HD 720p x264 AAC.mp4',
#  'C:\\Users\\harik\\Videos\\Serials\\Fantasy\\Foundation\\Foundation.S01E01.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Fantasy\\Foundation\\Foundation.S01E02.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Fantasy\\Foundation\\Foundation.S01E03.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\MCU\\Hawkeye\\Hawkeye.2021.S01E01.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\MCU\\Hawkeye\\Hawkeye.2021.S01E02.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\MCU\\Hawkeye\\Hawkeye.2021.S01E03.720p.WEB.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\MCU\\Hawkeye\\Hawkeye.2021.S01E05.WEBRip.x264-TORRENTGALAXY.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\MCU\\Hawkeye\\Hawkeye.S01E04.720p.HEVC.x265-MeGusta.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Doctor Who\\Doctor.Who.2005.S13E01.720p.WEBRip.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Doctor Who\\Doctor.Who.2005.S13E02.720p.HDTV.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Doctor Who\\Doctor.Who.2005.S13E03.HDTV.x264-TORRENTGALAXY.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Doctor Who\\Doctor.Who.2005.S13E04.720p.HDTV.x265-MiNX.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Doctor Who\\Doctor.Who.2005.S13E05.HDTV.x264-TORRENTGALAXY.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Doctor Who\\Doctor.Who.2005.S13E06.XviD-AFG.avi',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Star Trek Discovery\\Star.Trek.Discovery.S04E01.WEB.x264-TORRENTGALAXY.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Star Trek Discovery\\Star.Trek.Discovery.S04E02.WEB.x264-TORRENTGALAXY.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Star Trek Discovery\\Star.Trek.Discovery.S04E03.WEB.x264-TORRENTGALAXY.mkv',
#  'C:\\Users\\harik\\Videos\\Serials\\Sci-Fi\\Star Trek Discovery\\Star.Trek.Discovery.S04E04.720p.HEVC.x265-MeGusta[eztv.re].mkv']
