# %%
import pandas as pd
import json
import requests

# %%
link = "https://api.covid19tracker.in/data/static/timeseries.min.json"
object = requests.get(link)

# %%
data = object.content
# json.load(object.content)

# %%
json_data = json.loads(data)

# %%
pd.DataFrame(json_data["AN"]["dates"])
# Out:
#                                                2020-03-26  \
# delta   {'confirmed': 1, 'deceased': 0, 'recovered': 0...
# delta7  {'confirmed': 1, 'deceased': 0, 'recovered': 0...
# total   {'confirmed': 1, 'deceased': 0, 'recovered': 0...
#
#                                                2020-03-27  \
# delta   {'confirmed': 5, 'deceased': 0, 'recovered': 0...
# delta7  {'confirmed': 6, 'deceased': 0, 'recovered': 0...
# total   {'confirmed': 6, 'deceased': 0, 'recovered': 0...
#
#                                                2020-03-28  \
# delta   {'confirmed': 3, 'deceased': 0, 'recovered': 0...
# delta7  {'confirmed': 9, 'deceased': 0, 'recovered': 0...
# total   {'confirmed': 9, 'deceased': 0, 'recovered': 0...
#
#                                                2020-03-29  \
# delta   {'confirmed': 0, 'deceased': 0, 'recovered': 0...
# delta7  {'confirmed': 9, 'deceased': 0, 'recovered': 0...
# total   {'confirmed': 9, 'deceased': 0, 'recovered': 0...
#
# ...
