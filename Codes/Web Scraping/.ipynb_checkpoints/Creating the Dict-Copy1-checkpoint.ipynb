# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import requests
import bs4

# %%
for i in range(len(df)):
    with open('text.txt', 'a+') as f:
        #text.txt should be empty
        try:
            previous_word = df['Word'][i-1][0]
        except:
            pass
        
        current_word = df['Word'][i][0]
        a = f"<button class='word {df['Priorty'][i]}'>{df['Word'][i]}</button>"
        b = f"<p class='meaning hidden'>{df['Meaning'][i]}</p>"
        c = "<button class='close hidden'>harikesh</button>"
        d = f"<h2 class='letter', id='{current_word}'\">{current_word}</h2>"
        
        if previous_word==current_word:
            
            f.writelines( a+'\n'+b+'\n'+c+'\n')
        else:
            f.writelines(d+'\n'+ a+'\n'+b+'\n'+c+'\n')

# %%
pwd
# Out:
# 'C:\\Users\\harik\\Desktop\\Python\\Codes\\Web Scraping'

# %%
df = pd.read_csv('data/detailed_dic.csv')

# %%
# df['Choose the Right Synonym Final'] = df['Choose the Right Synonym'].apply(lambda x:'<br>'.join(x.split('\n')))

# %%
df
# Out:
#      Unnamed: 0       Word                                              First  \
# 0             0     Abject    sunk to or existing in a low state or condition
# 1             1    Acolyte  one who assists a member of the clergy in a li...
# 2             2    Adamant  a stone (such as a diamond) formerly believed ...
# 3             3   Addendum                                      a thing added
# 4             4   Adultery  voluntary sexual intercourse between a married...
# ..          ...        ...                                                ...
# 268         268     Unruly         not readily ruled, disciplined, or managed
# 269         269  Veritable  being in fact the thing named and not false, u...
# 270         270   Volition               the power of choosing or determining
# 271         271       Waif                           a stray person or animal
# 272         272      Wroth                                    intensely angry
#
#                                                 Second  \
# 0                                  cast down in spirit
# 1                  one who attends or assists a leader
# 2           an unbreakable or extremely hard substance
# 3                               a supplement to a book
# 4    sex between a married person and someone who i...
# ..                                                 ...
# 268                               difficult to control
# 269                                       actual, true
# 270              an act of making a choice or decision
# 271          an extremely thin and usually young woman
# 272                                    Oops! So Empty!
#
#                                                  Third  \
# 0    expressing or offered in a humble and often in...
# 1                                      Oops! So Empty!
# 2                                      Oops! So Empty!
# 3                                      Oops! So Empty!
# 4    voluntary sexual activity (as sexual intercour...
# ..                                                 ...
# 268                                    Oops! So Empty!
# 269                                    Oops! So Empty!
# 270              an act of making a choice or decision
# 271  a piece of property (such as property washed u...
# 272                                    Oops! So Empty!
#
#                                    Fourth                             Fifth  \
# 0                      very bad or severe  low in spirit, strength, or hope
# 1                         Oops! So Empty!                   Oops! So Empty!
# 2                         Oops! So Empty!                   Oops! So Empty!
# 3                         Oops! So Empty!                   Oops! So Empty!
# 4                         Oops! So Empty!                   Oops! So Empty!
# ..                                    ...                               ...
# 268                       Oops! So Empty!                   Oops! So Empty!
# 269                       Oops! So Empty!                   Oops! So Empty!
# 270  the power of choosing or determining                   Oops! So Empty!
# 271                       Oops! So Empty!                   Oops! So Empty!
# 272                       Oops! So Empty!                   Oops! So Empty!
#
#                                               Synonyms  \
# 0               base, humble, menial, servile, slavish
# 1    adherent, convert, disciple, epigone, follower...
# 2    adamantine, bullheaded, dogged, hard, hard-nos...
# 3    afterword, appendix, codicil, excursus, supple...
# 4    cheating, infidelity, misconduct, two-timing, ...
# ..                                                 ...
# 268  balky, contrary, contumacious, defiant, disobe...
# 269                                    Oops! So Empty!
# 270  accord, autonomy, choice, free will, self-dete...
# 271                                    Oops! So Empty!
# 272  angered, angry, apoplectic, ballistic, cheesed...
#
#                                               Antonyms  \
# 0               base, humble, menial, servile, slavish
# 1                                   coryphaeus, leader
# 2    acquiescent, agreeable, amenable, compliant, c...
# 3    foreword, introduction, preface, prologue \n (...
# 4                               faithfulness, fidelity
# ..                                                 ...
# 268  amenable, biddable, compliant, conformable, do...
# 269                                    Oops! So Empty!
# 270  accord, autonomy, choice, free will, self-dete...
# 271                                    Oops! So Empty!
# 272                      angerless, delighted, pleased
#
#                               Choose the Right Synonym Priorty  \
# 0    mean, ignoble, abject, sordid mean being below...   first
# 1                                      Oops! So Empty!   third
# 2    inflexible, obdurate, adamant mean unwilling t...   first
# 3                                      Oops! So Empty!   first
# 4                                      Oops! So Empty!   third
# ..                                                 ...     ...
# 268  unruly, ungovernable, intractable, refractory,...   first
# 269                                    Oops! So Empty!   third
# 270                                    Oops! So Empty!   third
# 271                                    Oops! So Empty!   third
# 272                                    Oops! So Empty!  second
#
#                         Choose the Right Synonym Final
# 0    mean, ignoble, abject, sordid mean being below...
# 1                                      Oops! So Empty!
# 2    inflexible, obdurate, adamant mean unwilling t...
# 3                                      Oops! So Empty!
# 4                                      Oops! So Empty!
# ..                                                 ...
# 268  unruly, ungovernable, intractable, refractory,...
# 269                                    Oops! So Empty!
# 270                                    Oops! So Empty!
# 271                                    Oops! So Empty!
# 272                                    Oops! So Empty!
#
# [273 rows x 12 columns]

# %%
# df.to_csv('data/detailed_dic.csv')

# %% [raw]
# <h2 class='letter' , id='A'">A</h2>
#         <button class='word first'>Abject</button>
#         <p class='meaning one hidden'>(Of Something Bad) Experienced Or Present To The Maximum Degree</p>
#         <p class='meaning two hidden'>sunk to or existing in a low state or condition</p>
#         <p class='meaning three hidden'>cast down in spirit</p>
#         <p class='meaning four hidden'>expressing or offered in a humble and often ingratiating spirit</p>
#         <p class='meaning five hidden'>Oops! So Empty!</p>
#         <button class='close hidden'>❌</button>
#         <button class= 'next hidden'>⏭</button>
#         <button class="show-modal hidden">Find Correct</button>
#         <div class="modal hidden">
#             <button class="close-modal">&times;</button>
#             <h1>Choose the Right Synonym</h1>
#             <p>
#                 mean, ignoble, abject, sordid mean being below the normal standards of human decency and dignity
#                 <br>
#                 <br>
#                 mean suggests small-mindedness, ill temper, or cupidity
#                 <br>
#                 mean and petty satire
#                 <br>
#                 <br>
#                 ignoble suggests a loss or lack of some essential high quality of mind or spirit
#                 <br>
#                 an ignoble scramble after material possessions
#                 <br>
#                 <br>
#                 abject may imply degradation, debasement, or servility
#                 <br>
#                 abject poverty
#                 <br><br>
#                 sordid is stronger than all of these in stressing physical or spiritual degradation and abjectness
#             <br>
#                 a sordid story of murder and revenge
#             </p>
#         </div>
#         <div class="overlay hidden"></div>

# %%
for i in range(len(df)):
    with open('text.txt', 'a+') as h:
        #text.txt should be empty
        if i == 0:
            previous_word = 'A'
        else:
            previous_word = df['Word'][i-1][0]
        
        current_word = df['Word'][i][0]
        text = df['Choose the Right Synonym Final']
        a = f"<button class='word {df['Priorty'][i]}'>{df['Word'][i]}</button>"
        b1 = f"<p class='meaning one hidden'>{df['First'][i]}</p>"
        b2 = f"<p class='meaning two hidden'>{df['Second'][i]}</p>"
        b3 = f"<p class='meaning three hidden'>{df['Third'][i]}</p>"
        b4 = f"<p class='meaning four hidden'>{df['Fourth'][i]}</p>"
        b5 = f"<p class='meaning five hidden'>{df['Fifth'][i]}</p>"
        c = "<button class='close hidden'>harikesh</button>"
        d = f"<h2 class='letter', id='{current_word}'>{current_word}</h2>"
        e = """<button class= 'next hidden'>xyz</button>
        <button class="show-modal hidden">Find Correct</button>
        <div class="modal hidden">
            <button class="close-modal">&times;</button>
            <h1>Choose the Right Synonym</h1>"""
        f = f"<p>\n{text[i]}\n</p>"
        g = """</div>
        <div class="overlay hidden"></div>"""

        if previous_word==current_word:
#             print('h')
            h.writelines(a+'\n'+b1+'\n'+b2+'\n'+b3+'\n'+b4+'\n'+b5+'\n'+c+'\n'+e+'\n'+f+'\n'+g+'\n')
        else:
#             print('j')
            h.writelines(d+'\n'+ a+'\n'+b1+'\n'+b2+'\n'+b3+'\n'+b4+'\n'+b5+'\n'+c+'\n'+e+'\n'+f+'\n'+g+'\n')
# Out:
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j
# j

# %%
b5
# Out:
# "<p class='meaning five hidden'>low in spirit, strength, or hope</p>"

# %%
print(g)
# Out:
# </div>
# <div class="overlay hidden"></div>

# %%
with open('text3.txt', 'a+') as f:
    f.writelines('hello\n')
    f.writelines('there\n')
