# %%
import re

# %%
with open('index.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
# text

# %%
pattern2 = r'''<h1>Choose the Right Synonym</h1>
                <p>
                        (.+)
                </p>'''
re.findall(pattern2, text)
# Out:
# ['Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
#  'Oops! So Empty!',
# ...

# %%
set(lists)
# Out:
# set()

# %%
pattern=r"Choose the Right(.+)p>"
re.findall(pattern, text)
# Out:
# []

# %%
pattern = r"one hidden'>sunk to or existing in a low state or condition</p>"
re.findall(pattern, text)
# Out:
# ["one hidden'>sunk to or existing in a low state or condition</p>"]
