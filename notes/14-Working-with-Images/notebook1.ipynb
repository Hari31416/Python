# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1D5AA6FD370>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
x = 780
y = 800
h = 1257
w = 1200

# %%
pc = mac.crop((x,y,w,h))

# %%
mac.paste(im=pc, box = (1000, 0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x1D5AA6FD370>

# %%
pwd
# Out:
# 'c:\\Users\\harik\\Desktop\\Python\\notes\\14-Working-with-Images'

# %%
cd c:\\Users\\harik\\Desktop
# Out:
# c:\Users\harik\Desktop

# %%
mac.save('mac.png')
